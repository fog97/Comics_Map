# %%
import pandas as pd
import numpy as np
import osmnx as ox
import pydeck as pdk

# %%
from datetime import date
today = date.today()
today_time = today.strftime("%m/%d/%Y")
today_time
# Out:
# '01/31/2023'

# %% [markdown]
# # Layer Unici

# %% [markdown]
# ## BUS

# %%
places=["Turin,Italy"]
tags = {"public_transport":"platform",
        "bus":"yes",
        "node":True}

all_pois = ox.geometries_from_place(places,tags)
bus=pd.DataFrame(all_pois)
bus=bus[["name","public_transport","geometry"]].reset_index()
bus=bus[bus.element_type=="node"]
bus["lat"]=bus.geometry.apply(lambda x:str(x).split("(")[1].replace(")","").split(" ")[1])
bus["lon"]=bus.geometry.apply(lambda x:str(x).split("(")[1].replace(")","").split(" ")[0])
classe=["Bus"]*len(bus)
bus["Classe"]=classe
bus=bus[["Classe","lat","lon","name"]]
bus.head()
# Out:
#   Classe         lat        lon              name
# 0    Bus  45.0408626  7.6475073        Filadelfia
# 1    Bus  45.0441167  7.6495573       Sebastopoli
# 2    Bus  45.0434116  7.6493087       Sebastopoli
# 3    Bus  45.0367158  7.6026568        Pancalieri
# 4    Bus  45.0282513   7.621681  Settembrini C.18

# %% [markdown]
# # Treni e Metro

# %%
tags2 = {"public_transport":"station"}
places=["Turin,Italy"]
all_pois2 = ox.geometries_from_place(places,tags2)
point2=pd.DataFrame(all_pois2).reset_index()
point2=point2[point2.element_type=="node"]
point2=point2[["name","public_transport","geometry","railway"]].reset_index()

point2["lat"]=point2.geometry.apply(lambda x:str(x).split("(")[1].replace(")","").split(" ")[1])
point2["lon"]=point2.geometry.apply(lambda x:str(x).split("(")[1].replace(")","").split(" ")[0])
train=point2

classe=["Train"]*len(train)
train["Classe"]=classe
train=train[["Classe","lat","lon","name"]]
train.head()
# Out:
#   Classe         lat        lon                       name
# 0  Train  45.0265963  7.6568231            Torino Lingotto
# 1  Train  45.1220894  7.7137959               Torino Stura
# 2  Train  45.0995384  7.6871609  Torino Rebaudengo Fossata
# 3  Train   45.060896  7.6775203         Torino Porta Nuova

# %% [markdown]
# ## Parcheggi

# %%
tags3 = {"amenity":"parking"}

all_pois3 = ox.geometries_from_place(places,tags3)
parcheggi=pd.DataFrame(all_pois3).reset_index()
parcheggi_nodi=parcheggi[parcheggi.element_type=="node"]
parcheggi_way=parcheggi[parcheggi.element_type=="way"]
parcheggi_relation=parcheggi[parcheggi.element_type=="relation"]
parcheggi_nodi=parcheggi_nodi[["name","geometry"]]
parcheggi_nodi["lat"]=parcheggi_nodi.geometry.apply(lambda x:str(x).split("(")[1].replace(")","").split(" ")[1])
parcheggi_nodi["lon"]=parcheggi_nodi.geometry.apply(lambda x:str(x).split("(")[1].replace(")","").split(" ")[0])

parcheggi_way=parcheggi_way[["name","geometry","email"]]
parcheggi_way["lat"]=parcheggi_way.geometry.apply(lambda x:str(x).split("(")[2].split(",")[0].split(" ")[1])
parcheggi_way["lon"]=parcheggi_way.geometry.apply(lambda x:str(x).split("(")[2].split(",")[0].split(" ")[0])

parcheggi_relation=parcheggi_relation[["name","geometry"]]
parcheggi_relation["split"]=parcheggi_relation.geometry.apply(lambda x:str(x).split("(")[0])
parcheggi_polygon=parcheggi_relation[parcheggi_relation.split=="POLYGON "]
parcheggi_multipolygon=parcheggi_relation[parcheggi_relation.split=="MULTIPOLYGON "]
parcheggi_polygon["lat"]=parcheggi_polygon.geometry.apply(lambda x:str(x).split("(")[2].split(",")[0].split(" ")[1])
parcheggi_polygon["lon"]=parcheggi_polygon.geometry.apply(lambda x:str(x).split("(")[2].split(",")[0].split(" ")[0])
parcheggi_polygon=parcheggi_polygon[["name","geometry","lat","lon"]]
parcheggi_multipolygon["lat"]=parcheggi_multipolygon.geometry.apply(lambda x:str(x).split("(")[3].split(",")[0].split(" ")[1])
parcheggi_multipolygon["lon"]=parcheggi_multipolygon.geometry.apply(lambda x:str(x).split("(")[3].split(",")[0].split(" ")[0])
parcheggi_multipolygon=parcheggi_multipolygon[["name","geometry","lat","lon"]]
parcheggi_complete=pd.concat([parcheggi_nodi, parcheggi_way,parcheggi_polygon,parcheggi_multipolygon], ignore_index=True)
classe=["Parcheggio"]*len(parcheggi_complete)
parcheggi_complete["Classe"]=classe
parcheggi_complete=parcheggi_complete[["Classe","lat","lon","name"]]
parcheggi_complete.head()
# Out:
# C:\Users\lucaf\AppData\Local\Temp\ipykernel_4416\3048244685.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parcheggi_polygon["lat"]=parcheggi_polygon.geometry.apply(lambda x:str(x).split("(")[2].split(",")[0].split(" ")[1])
# C:\Users\lucaf\AppData\Local\Temp\ipykernel_4416\3048244685.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parcheggi_polygon["lon"]=parcheggi_polygon.geometry.apply(lambda x:str(x).split("(")[2].split(",")[0].split(" ")[0])
# C:\Users\lucaf\AppData\Local\Temp\ipykernel_4416\3048244685.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parcheggi_multipolygon["lat"]=parcheggi_multipolygon.geometry.apply(lambda x:str(x).split("(")[3].split(",")[0].split(" ")[1])
# C:\Users\lucaf\AppData\Local\Temp\ipykernel_4416\3048244685.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   parcheggi_multipolygon["lon"]=parcheggi_multipolygon.geometry.apply(lambda x:str(x).split("(")[3].split(",")[0].split(" ")[0])
#        Classe         lat        lon        name
# 0  Parcheggio  45.0777457  7.7026626         NaN
# 1  Parcheggio  45.0791337  7.7014438         NaN
# 2  Parcheggio  45.0634661  7.6806902         NaN
# 3  Parcheggio  45.0641024  7.6789702         NaN
# 4  Parcheggio  45.0650308  7.6873332  Valdo Fusi

# %% [markdown]
# ## Dataset Unico

# %%
map_data=pd.concat([parcheggi_complete, bus,train], ignore_index=True)

# %%
map_data.head()
# Out:
#        Classe         lat        lon        name
# 0  Parcheggio  45.0777457  7.7026626         NaN
# 1  Parcheggio  45.0791337  7.7014438         NaN
# 2  Parcheggio  45.0634661  7.6806902         NaN
# 3  Parcheggio  45.0641024  7.6789702         NaN
# 4  Parcheggio  45.0650308  7.6873332  Valdo Fusi

# %%
map_data.to_csv("map_data.csv")

# %%
map_data=pd.read_csv("map_data.csv", keep_default_na=False,index_col=0)
map_data['lat'] = map_data['lat'].astype(float)
map_data['lon'] = map_data['lon'].astype(float)
# Out:
#        Classe        lat       lon        name
# 0  Parcheggio  45.077746  7.702663
# 1  Parcheggio  45.079134  7.701444
# 2  Parcheggio  45.063466  7.680690
# 3  Parcheggio  45.064102  7.678970
# 4  Parcheggio  45.065031  7.687333  Valdo Fusi

# %%
for index,row in map_data.iterrows():
    if row["name"]=="":
        map_data.loc[index,"name"]=map_data.loc[index,"Classe"]
map_data.head()
# Out:
#        Classe        lat       lon        name
# 0  Parcheggio  45.077746  7.702663  Parcheggio
# 1  Parcheggio  45.079134  7.701444  Parcheggio
# 2  Parcheggio  45.063466  7.680690  Parcheggio
# 3  Parcheggio  45.064102  7.678970  Parcheggio
# 4  Parcheggio  45.065031  7.687333  Valdo Fusi

# %% [markdown]
# ## Icone

# %%
Bus_icon = "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png"

Bus_icon_data = {

    "url": Bus_icon,
    "width": 32,
    "height": 37,
    "anchorY": 'auto',
}

# %%
Metro_icon = "https://upload.wikimedia.org/wikipedia/commons/5/57/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Subway_%E2%80%93_Transportation_%E2%80%93_Light.png"

Metro_icon_data = {

    "url": Metro_icon,
    "width": 32,
    "height": 37,
    "anchorY": 'auto',
}

# %%
Train_icon = "https://upload.wikimedia.org/wikipedia/commons/1/16/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Train_%E2%80%93_Transportation_%E2%80%93_Light.png"

Train_icon_data = {

    "url": Train_icon,
    "width": 32,
    "height": 37,
    "anchorY": 'auto',
}

# %%
Parcheggi_icon = "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png"

Parcheggi_icon_data = {

    "url": Parcheggi_icon,
    "width": 32,
    "height": 37,
    "anchorY": 'auto',
}

# %% [markdown]
# # Assegno le icone alle Classi

# %%
icon_data = []
for index,row in map_data.iterrows():
  if row["Classe"]=="Parcheggio":
    icon_data.append(Parcheggi_icon_data)
  elif row["Classe"]=="Bus":
    icon_data.append(Bus_icon_data)
  elif row["Classe"]=="Train":
    icon_data.append(Train_icon_data)
  elif row["Classe"]=="Metro":
    icon_data.append(Metro_icon_data)

# %%
map_data["icon_data"]=icon_data
map_data.Classe.unique()
# Out:
# array(['Parcheggio', 'Bus', 'Train'], dtype=object)

# %% [markdown]
# ## Preparazione del layer

# %% [markdown]
# Tutti i mezzi

# %%
Nav_Points = pdk.Layer(
    type="IconLayer",
    data=map_data,
    get_icon="icon_data",
    get_size=10,
    size_scale=3,
    get_position=["lon", "lat"],
    pickable=True,
)

# %% [markdown]
# Origin Layer e Initial State

# %%
import pandas as pd
import geopandas
import folium
import matplotlib.pyplot as plt
import pydeck as pdk
INITIAL_VIEW_STATE = pdk.ViewState(
  latitude=45.02891677040412, 
  longitude=7.664243711338131,
  zoom=10,
  max_zoom=16,
  pitch=45,
  bearing=0
)

origin_url = "https://upload.wikimedia.org/wikipedia/commons/9/9e/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Pin_%E2%80%93_Tourism_%E2%80%93_Light.png"

origin_icon = {

    "url": origin_url,
    "width": 32,
    "height": 37,
    "anchorY": 'auto',
}


origin=pd.DataFrame({"lon":7.664243711338131,"lat":45.02891677040412,"name":"Esposizioni Novegro"}, index=[0])
import pydeck as pdk
import pandas as pd

icon_data = []
for index,row in origin.iterrows():
  if index==0:
    icon_data.append(origin_icon)

origin["icon_data"]=icon_data




data=origin[["lat","lon","name","icon_data"]]

view_state = INITIAL_VIEW_STATE

origin_layer = pdk.Layer(
    type="IconLayer",
    data=data,
    get_icon="icon_data",
    get_size=15,
    size_scale=3,
    get_position=["lon", "lat"],
    pickable=True,
)

# %% [markdown]
# # Mappa

# %%
pdk.Deck(layers=[Nav_Points,origin_layer], map_style='road',initial_view_state=INITIAL_VIEW_STATE, tooltip={"text": "{name}"})
# Out:
# {
#   "initialViewState": {
#     "bearing": 0,
#     "latitude": 45.02891677040412,
#     "longitude": 7.664243711338131,
#     "maxZoom": 16,
#     "pitch": 45,
#     "zoom": 10
#   },
#   "layers": [
#     {
#       "@@type": "IconLayer",
#       "data": [
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0777457,
#           "lon": 7.7026626,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0791337,
#           "lon": 7.7014438,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0634661,
#           "lon": 7.6806902,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0641024,
#           "lon": 7.6789702,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0650308,
#           "lon": 7.6873332,
#           "name": "Valdo Fusi"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.1176687,
#           "lon": 7.7373549,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.050652,
#           "lon": 7.6837626,
#           "name": "5\u00b0 Padiglione"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0304057,
#           "lon": 7.6985475,
#           "name": "park to S11 and S12 path"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0890164,
#           "lon": 7.6704852,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0312776,
#           "lon": 7.7037518,
#           "name": "park to S11 and S12 path"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0642036,
#           "lon": 7.6863699,
#           "name": "Valdo Fusi"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0988172,
#           "lon": 7.7115019,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0428369,
#           "lon": 7.678053,
#           "name": "D'Azeglio - Galilei"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.063382,
#           "lon": 7.6834279,
#           "name": "Piazza Bodoni"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0872521,
#           "lon": 7.6819114,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0864397,
#           "lon": 7.6843549,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.08722,
#           "lon": 7.6822064,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0863318,
#           "lon": 7.6833142,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0681503,
#           "lon": 7.678391,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0716774,
#           "lon": 7.6160705,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.071721,
#           "lon": 7.6172373,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0932272,
#           "lon": 7.688534,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.1025245,
#           "lon": 7.7287602,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0494839,
#           "lon": 7.6555122,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0688737,
#           "lon": 7.7014714,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0730992,
#           "lon": 7.6958733,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.070367,
#           "lon": 7.706222,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0719601,
#           "lon": 7.7052082,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.069437,
#           "lon": 7.6991464,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.070321,
#           "lon": 7.6989886,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0709789,
#           "lon": 7.6999564,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0687686,
#           "lon": 7.7000074,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0650472,
#           "lon": 7.6854844,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.1215584,
#           "lon": 7.7135716,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0985971,
#           "lon": 7.637087,
#           "name": "Parcheggio COOP"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0551469,
#           "lon": 7.7105161,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0552184,
#           "lon": 7.7118606,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0552947,
#           "lon": 7.7115763,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0554258,
#           "lon": 7.7084048,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.055522,
#           "lon": 7.7110097,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0560118,
#           "lon": 7.7063366,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0564722,
#           "lon": 7.7121378,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0571751,
#           "lon": 7.7055282,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0578919,
#           "lon": 7.7047514,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0580131,
#           "lon": 7.7047313,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0448933,
#           "lon": 7.6558278,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0455947,
#           "lon": 7.6542371,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0627355,
#           "lon": 7.6779118,
#           "name": "Parcheggio Torino Porta Nuova"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0876085,
#           "lon": 7.683766,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0901524,
#           "lon": 7.6862058,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0894662,
#           "lon": 7.6843426,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.088137,
#           "lon": 7.6828623,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0932403,
#           "lon": 7.6874846,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0930737,
#           "lon": 7.6873907,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0925397,
#           "lon": 7.6884757,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0936976,
#           "lon": 7.689456,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0935271,
#           "lon": 7.6892844,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0934684,
#           "lon": 7.6893514,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0937941,
#           "lon": 7.6904753,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0923285,
#           "lon": 7.6880506,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0916431,
#           "lon": 7.6871332,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0917056,
#           "lon": 7.687144,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0917529,
#           "lon": 7.687152,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0912776,
#           "lon": 7.6879674,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0912492,
#           "lon": 7.6883885,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0913931,
#           "lon": 7.6878467,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0915219,
#           "lon": 7.6878762,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.091787,
#           "lon": 7.6883295,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0918021,
#           "lon": 7.6881015,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0922907,
#           "lon": 7.6880398,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0909349,
#           "lon": 7.6893005,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0863086,
#           "lon": 7.6776705,
#           "name": "Parcheggio Fortino"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0791246,
#           "lon": 7.6638832,
#           "name": "Le Chiuse"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0862058,
#           "lon": 7.6778221,
#           "name": "Hotel Fortino"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.1123025,
#           "lon": 7.6573976,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0642687,
#           "lon": 7.6659975,
#           "name": "Parcheggio Stati Uniti"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0496513,
#           "lon": 7.6667088,
#           "name": "Disabled parking"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0645196,
#           "lon": 7.6925526,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0734451,
#           "lon": 7.6820148,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0734628,
#           "lon": 7.6816353,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0765381,
#           "lon": 7.680295,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.076841,
#           "lon": 7.6801851,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0748759,
#           "lon": 7.6797143,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0747476,
#           "lon": 7.6836248,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0702569,
#           "lon": 7.6752323,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0776016,
#           "lon": 7.6771578,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0775755,
#           "lon": 7.6772342,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0777728,
#           "lon": 7.6769771,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0777501,
#           "lon": 7.6770413,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0775888,
#           "lon": 7.6771947,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0702114,
#           "lon": 7.6753677,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.073908,
#           "lon": 7.6838465,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0733943,
#           "lon": 7.6842066,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0703374,
#           "lon": 7.6767987,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0762833,
#           "lon": 7.6794004,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0763219,
#           "lon": 7.6792882,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0686751,
#           "lon": 7.6561725,
#           "name": "Parcheggio Bixio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0697998,
#           "lon": 7.691989,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0570572,
#           "lon": 7.6570655,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0797715,
#           "lon": 7.6916646,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0558284,
#           "lon": 7.6777849,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0568497,
#           "lon": 7.6892343,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0779319,
#           "lon": 7.6302628,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0779092,
#           "lon": 7.6312981,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0193765,
#           "lon": 7.6594513,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.1078412,
#           "lon": 7.6695541,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0564733,
#           "lon": 7.7082154,
#           "name": "Parcheggio"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/c/c7/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Parking_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0359904,
#           "lon": 7.6813491,
#           "name": "Parcheggio Crai"
#         },
#         {
#           "Classe": "Parcheggio",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
# ...
#           "lon": 7.6646938,
#           "name": "Inghilterra"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0731851,
#           "lon": 7.6645323,
#           "name": "Beaumont"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0701192,
#           "lon": 7.6642284,
#           "name": "Cavalli Est"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0665267,
#           "lon": 7.6881444,
#           "name": "Bus"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0890488,
#           "lon": 7.676674,
#           "name": "Dora"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.1201332,
#           "lon": 7.7109169,
#           "name": "Torino, Stura"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.049718,
#           "lon": 7.6814199,
#           "name": "Bus"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0984658,
#           "lon": 7.6850661,
#           "name": "Fermata 3585 - Fossata"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0251752,
#           "lon": 7.6562136,
#           "name": "Torino"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.1200937,
#           "lon": 7.7109361,
#           "name": "Torino, Stura"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0687848,
#           "lon": 7.6907352,
#           "name": "Verdi"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.057802,
#           "lon": 7.677025,
#           "name": "Marconi"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0576258,
#           "lon": 7.677191,
#           "name": "Marconi"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0800569,
#           "lon": 7.7141321,
#           "name": "Carcano"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0964724,
#           "lon": 7.7002385,
#           "name": "Donatore di Sangue Cap."
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0940641,
#           "lon": 7.7166067,
#           "name": "Parco Della Confluenza"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0916249,
#           "lon": 7.7151015,
#           "name": "Paroletti"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0915735,
#           "lon": 7.7149371,
#           "name": "Paroletti"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.098024,
#           "lon": 7.7011514,
#           "name": "Monte Rosa"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0701351,
#           "lon": 7.6656434,
#           "name": "Porta Susa sud"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0780541,
#           "lon": 7.7099186,
#           "name": "Nievo est"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0724343,
#           "lon": 7.6668933,
#           "name": "Bolzano Capolinea"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0298592,
#           "lon": 7.6661866,
#           "name": "Via Nizza-Lingotto Fiere"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0630605,
#           "lon": 7.6773909,
#           "name": "C.So V.Eman. Porta Nuova"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0610701,
#           "lon": 7.685213,
#           "name": "Vittorio Emanuele II"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0635445,
#           "lon": 7.6768312,
#           "name": "Vittorio Emanuele II Capolinea"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0590653,
#           "lon": 7.6564937,
#           "name": "Braccini"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0562033,
#           "lon": 7.6549565,
#           "name": "Torricelli"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0538254,
#           "lon": 7.6550366,
#           "name": "Rosselli"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.053688,
#           "lon": 7.6547597,
#           "name": "Rosselli"
#         },
#         {
#           "Classe": "Bus",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/b/b3/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Bus_Stop_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0561636,
#           "lon": 7.6546363,
#           "name": "Torricelli"
#         },
#         {
#           "Classe": "Train",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/1/16/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Train_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0265963,
#           "lon": 7.6568231,
#           "name": "Torino Lingotto"
#         },
#         {
#           "Classe": "Train",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/1/16/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Train_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.1220894,
#           "lon": 7.7137959,
#           "name": "Torino Stura"
#         },
#         {
#           "Classe": "Train",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/1/16/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Train_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.0995384,
#           "lon": 7.6871609,
#           "name": "Torino Rebaudengo Fossata"
#         },
#         {
#           "Classe": "Train",
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/1/16/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Train_%E2%80%93_Transportation_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.060896,
#           "lon": 7.6775203,
#           "name": "Torino Porta Nuova"
#         }
#       ],
#       "getIcon": "@@=icon_data",
#       "getPosition": "@@=[lon, lat]",
#       "getSize": 10,
#       "id": "89abea21-7f8a-4ed5-bbdd-06dd85d6ea0e",
#       "pickable": true,
#       "sizeScale": 3
#     },
#     {
#       "@@type": "IconLayer",
#       "data": [
#         {
#           "icon_data": {
#             "anchorY": "auto",
#             "height": 37,
#             "url": "https://upload.wikimedia.org/wikipedia/commons/9/9e/Map_marker_icon_%E2%80%93_Nicolas_Mollet_%E2%80%93_Pin_%E2%80%93_Tourism_%E2%80%93_Light.png",
#             "width": 32
#           },
#           "lat": 45.02891677040412,
#           "lon": 7.664243711338131,
#           "name": "Esposizioni Novegro"
#         }
#       ],
#       "getIcon": "@@=icon_data",
#       "getPosition": "@@=[lon, lat]",
#       "getSize": 15,
#       "id": "85ab3997-868f-4945-a105-c600d7f9ba62",
#       "pickable": true,
#       "sizeScale": 3
#     }
#   ],
#   "mapProvider": "carto",
#   "mapStyle": "https://basemaps.cartocdn.com/gl/voyager-gl-style/style.json",
#   "views": [
#     {
#       "@@type": "MapView",
#       "controller": true
#     }
#   ]
# }

# %% [markdown]
# ## TEST PRESONALIZZAZIONE

# %%
a=input()
b=input()
c=input()
d=input()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [43], line 1
# ----> 1 a=input()
#       2 b=input()
#       3 c=input()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1177, in Kernel.raw_input(self, prompt)
#    1173 if not self._allow_stdin:
#    1174     raise StdinNotImplementedError(
#    1175         "raw_input was called, but this frontend does not support input requests."
#    1176     )
# -> 1177 return self._input_request(
#    1178     str(prompt),
#    1179     self._parent_ident["shell"],
#    1180     self.get_parent("shell"),
#    1181     password=False,
#    1182 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\kernelbase.py:1219, in Kernel._input_request(self, prompt, ident, parent, password)
#    1216             break
#    1217 except KeyboardInterrupt:
#    1218     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219     raise KeyboardInterrupt("Interrupted by user") from None
#    1220 except Exception:
#    1221     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
list_values=[a,b,c,d]
print(list_values)
test=map_data[map_data.Classe.isin(list_values)]
test.Classe.unique()
# Out:
# ['', '', '', '']
# array([], dtype=object)

# %%
Nav_Points_part = pdk.Layer(
    type="IconLayer",
    data=test,
    get_icon="icon_data",
    get_size=10,
    size_scale=3,
    get_position=["lon", "lat"],
    pickable=True,
)

# %%
pdk.Deck(layers=[Nav_Points_part,origin_layer], map_style='road',initial_view_state=INITIAL_VIEW_STATE, tooltip={"text": "{name}"})
# Out:
# {
#   "initialViewState": {
#     "bearing": 0,
#     "latitude": 45.47185532715593,
#     "longitude": 9.275071955673953,
#     "maxZoom": 16,
#     "pitch": 45,
#     "zoom": 10
#   },
#   "layers": [
#     {
#       "@@type": "IconLayer",
#       "data": [],
#       "getIcon": "@@=icon_data",
#       "getPosition": "@@=[lon, lat]",
#       "getSize": 10,
#       "id": "900a566e-3d13-425c-b7d0-fe03b8831e4e",
#       "pickable": true,
#       "sizeScale": 3
#     },
#     {
#       "@@type": "IconLayer",
#       "data": [
#         {
#           "icon_data": NaN,
#           "lat": 45.47185532715593,
#           "lon": 9.275071955673953,
#           "name": "Esposizioni Novegro"
#         }
#       ],
#       "getIcon": "@@=icon_data",
#       "getPosition": "@@=[lon, lat]",
#       "getSize": 10,
#       "id": "87bf026b-0eed-42ab-a805-1d6961e5dc24",
#       "pickable": true,
#       "sizeScale": 3
#     }
#   ],
#   "mapProvider": "carto",
#   "mapStyle": "https://basemaps.cartocdn.com/gl/voyager-gl-style/style.json",
#   "views": [
#     {
#       "@@type": "MapView",
#       "controller": true
#     }
#   ]
# }
